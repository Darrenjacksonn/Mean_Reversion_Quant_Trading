# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf
import numpy as np
import pandas as pd

# %%
SPL = yf.download('SPY')
SPL
# Out:
# C:\Users\DarrenJackson\Desktop\Coding\Projects\Quantitative Trading\Project_1\venviro2\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.840681
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.017351
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.070366
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.335352
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.441380
# ...                ...         ...         ...         ...         ...
# ...

# %%
SPL = yf.download('SPY', interval = '1d')
SPL
# Out:
# C:\Users\DarrenJackson\Desktop\Coding\Projects\Quantitative Trading\Project_1\venviro2\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.840677
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.017351
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.070356
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.335363
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.441372
# ...                ...         ...         ...         ...         ...
# ...

# %%
SPL['Close'].to_frame().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
SPL['Adj Close'].to_frame().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
spl_close = SPL['Close'].to_frame()
spl_close
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-02-09  501.200012
# 2024-02-12  500.980011
# 2024-02-13  494.079987
# 2024-02-14  498.570007
# 2024-02-15  502.010010
#
# [7818 rows x 1 columns]

# %%
spl_daily_returns = SPL['Close'].pct_change().mul(100).to_frame().dropna()
spl_daily_returns = spl_daily_returns.rename(columns = {'Close' : 'Daily % Returns'})
spl_daily_returns
# Out:
#             Daily % Returns
# Date
# 1993-02-01         0.711238
# 1993-02-02         0.211864
# 1993-02-03         1.057082
# 1993-02-04         0.418410
# 1993-02-05        -0.069444
# ...                     ...
# 2024-02-09         0.577943
# 2024-02-12        -0.043895
# 2024-02-13        -1.377305
# 2024-02-14         0.908764
# 2024-02-15         0.689974
#
# [7817 rows x 1 columns]

# %%
spl_daily_returns.plot(kind = 'hist', bins = 1000, title = 'Daily Percentage Returns')
plt.show()

# %%
average_daily_returns = spl_daily_returns.mean()
average_daily_returns
# Out:
# Close    0.038173
# dtype: float64

# %%
# If you invested €1 in 1993, you would have: 7812
returns = 1 * average_daily_returns * 7812
returns
# Out:
# Close    298.21006
# dtype: float64

# %%
spl_close
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-02-09  501.200012
# 2024-02-12  500.980011
# 2024-02-13  494.079987
# 2024-02-14  498.570007
# 2024-02-15  502.010010
#
# [7818 rows x 1 columns]

# %%
spl_norm_close = spl_close.div(spl_close.iloc[0]).mul(100)
spl_norm_close
# Out:
#                   Close
# Date
# 1993-01-29   100.000000
# 1993-02-01   100.711238
# 1993-02-02   100.924609
# 1993-02-03   101.991465
# 1993-02-04   102.418208
# ...                 ...
# 2024-02-09  1140.711265
# 2024-02-12  1140.210551
# 2024-02-13  1124.506371
# 2024-02-14  1134.725479
# 2024-02-15  1142.554788
#
# [7818 rows x 1 columns]

# %%
spl_norm_close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
daily_returns_variance = spl_daily_returns.var() # risk metric
daily_returns_variance
# Out:
# Close    1.400278
# dtype: float64

# %%
average_daily_returns
# Out:
# Close    0.038173
# dtype: float64

# %%
average_monthly_returns_est = average_daily_returns * 20
average_monthly_returns_est
# Out:
# Close    0.763467
# dtype: float64

# %%
SPL_monthly = yf.download('SPY', interval = '1mo')
SPL_monthly
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-02-01   43.968750   45.125000   42.812500   44.406250   25.105692
# 1993-03-01   44.562500   45.843750   44.218750   45.187500   25.547380
# 1993-04-01   45.250000   45.250000   43.281250   44.031250   25.011253
# 1993-05-01   44.093750   45.656250   43.843750   45.218750   25.685789
# 1993-06-01   45.375000   45.812500   44.218750   45.062500   25.597036
# ...                ...         ...         ...         ...         ...
# 2023-10-01  426.619995  438.140015  409.209991  418.200012  416.511292
# 2023-11-01  419.200012  458.320007  418.649994  456.399994  454.557037
# 2023-12-01  455.769989  477.549988  454.309998  475.309998  473.390686
# 2024-01-01  472.160004  491.619995  466.429993  482.880005  482.880005
# 2024-02-01  484.630005  503.500000  483.799988  502.170013  502.170013
#
#                 Volume
# Date
# ...

# %%
SPL_monthly_returns = SPL_monthly['Close'].pct_change().mul(100).to_frame().dropna()
SPL_monthly_returns
# Out:
#                Close
# Date
# 1993-03-01  1.759324
# 1993-04-01 -2.558783
# 1993-05-01  2.696948
# 1993-06-01 -0.345543
# 1993-07-01 -0.485437
# ...              ...
# 2023-10-01 -2.170861
# 2023-11-01  9.134381
# 2023-12-01  4.143296
# 2024-01-01  1.592646
# 2024-02-01  3.994783
#
# [372 rows x 1 columns]

# %%
average_monthly_returns = SPL_monthly_returns.mean()
average_monthly_returns
# Out:
# Close    0.748804
# dtype: float64
