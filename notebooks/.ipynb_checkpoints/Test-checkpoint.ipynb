# %%
import sys
sys.path.append('data_exploration')
from stock_info import StockInfo
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
stock = StockInfo('MSFT',start='2010-01-01',end='2012-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
stock.data
# Out:
#                  MSFT
# Date
# 2010-01-04  23.431589
# 2010-01-05  23.439156
# 2010-01-06  23.295309
# 2010-01-07  23.053047
# 2010-01-08  23.212038
# ...               ...
# 2011-12-23  20.651659
# 2011-12-27  20.659588
# 2011-12-28  20.485041
# 2011-12-29  20.643721
# 2011-12-30  20.596123
#
# [504 rows x 1 columns]

# %%
stock.plot_stock_price()

# %%
stock.mean()
# Out:
# MSFT    20.534879
# dtype: float64

# %%
stock.variance()
# Out:
# MSFT    1.726544
# dtype: float64

# %%
stock.std()
# Out:
# MSFT    1.31398
# dtype: float64

# %%
stock.plot_returns()

# %%
stock.mean_of_returns()
# Out:
# MSFT   -0.015434
# dtype: float64

# %%
stock.variance_of_returns()
# Out:
# MSFT    2.042977
# dtype: float64

# %%
stock.std_of_returns()
# Out:
# MSFT    1.429328
# dtype: float64
